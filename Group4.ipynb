# %% [markdown]
# #1.Write a python program to create an array and convert to a desired dimension.

# %%
import numpy as np
ar = np.array([[8,9,10],[11,12,13]])
ar
# Out:
# array([[ 8,  9, 10],
#        [11, 12, 13]])

# %%
reshaped_ar = ar.reshape(3,2)
reshaped_ar
# Out:
# array([[ 8,  9],
#        [10, 11],
#        [12, 13]])

# %% [markdown]
# #2.To create an array and extract particular set of elements from the array.

# %%
ir = np.array([[8,9],[10,11],[12,13]])
ir
# Out:
# array([[ 8,  9],
#        [10, 11],
#        [12, 13]])

# %%
sr = ir[[0,1],[1,1]]
sr
# Out:
# array([ 9, 11])

# %% [markdown]
# #3. To create a dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({'Country':['Russia','Colombia','Chile','Equador','Nigeria'],
     'Rank':[121,40,100,130,11]})
df
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Colombia    40
# 2     Chile   100
# 3   Equador   130
# 4   Nigeria    11

# %% [markdown]
# #4.From the given data set and answer the following questions. Show the steps taken to produce your final answer.

# %%
ds=pd.read_csv('/content/diabetes_model.csv')
ds
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# a. Display the Glucose level and the Age for the samples having the index ranging from 45 to 60.

# %%
ga=ds[['Glucose','Age']]
ga[45:61]
# Out:
#     Glucose  Age
# 45      137   21
# 46      145   70
# 47      113   22
# 48       96   27
# 49      131   26
# 50      113   21
# 51      120   34
# 52       95   24
# 53      155   46
# 54      100   46
# 55      184   49
# 56       90   29
# 57      142   61
# 58      125   27
# 59      101   26
# 60      188   22

# %% [markdown]
# b. How many patients in the data are having the blood pressure level above 120?

# %%
ds.value_counts(ds['BloodPressure']>120)
# Out:
# BloodPressure
# False    613
# True       1
# dtype: int64

# %% [markdown]
# c. Find the minimum and maximum value of insulin level in the data.

# %%
mx=ds['Insulin'].max()
mx
# Out:
# 846

# %%
mn=ds['Insulin'].min()
mn
# Out:
# 0

# %% [markdown]
# d. Create a histogram of "Age".

# %%
plt.hist(ds['Age'])
plt.xlim(10,100)
plt.title('Age of People')
plt.xlabel('ages')
plt.ylabel('counts')
plt.grid()

# %% [markdown]
# e.Create a scatter plot of "BMI" vs "Glucose".

# %%
plt.scatter(ds['BMI'],ds['Glucose'])
plt.title('"BMI" vs "Glucose"')
plt.xlabel('BMI')
plt.ylabel('Glucose')
